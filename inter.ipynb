# %%
dictionary = {'apple':15,"bananas":14,'grapes':45}
dictionary['bananas']
# Out:
# 14

# %%
dictionary['oranges'] = 20
len(dictionary)
# Out:
# 4

# %%
'grapes' in dictionary
# Out:
# True

# %%
dictionary['pears']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dictionary['pears']
#
# KeyError: 'pears'

# %%
dictionary.get('pears',0)
# Out:
# 0

# %%
fruits = list(dictionary.keys())
fruits.sort()
print(fruits)
# Out:
# ['apple', 'bananas', 'grapes']

# %%
del dictionary['apple']
'apple' in dictionary
# Out:
# False

# %%
def add_fruits(inver)
